# %%
import re
import sys
import os
import csv
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import date
today = date.today()
now = datetime.now()
date1 = today.strftime("%Y-%m-%d")
now1 = now.strftime("%H:%M:%S")
#path = '/home/njm3/Desktop/mithras_test'

# %%
analysis = """"""

# %%
#np.set_printoptions(formatter={'float64': lambda x: "{0:0.3f}".format(x)})
def char_range(c1, c2):
    """Generates the characters from `c1` to `c2`, inclusive."""
    for c in range(ord(c1), ord(c2)+1):
        yield chr(c)

def arrconv(array):
    for i in range(len(array)):
        tes1 = np.array([np.float_(array[i])])
        tes1 = str(tes1)
        tes1 = tes1.translate({ord('['): None})
        tes1 = tes1.translate({ord(']'): None})
        print('<d>'+tes1+'</d>')
        
def col_div(aa1,aa2):
    div_list = []
    for i in range(len(aa1)):
                   div_list.append(np.float64(aa1[i])/np.float64(aa2[i]))
                   c = np.float64(aa1[i])/np.float64(aa2[i])
                   #print(c)
    return(div_list) 
        
        
def pzfx_maker(file): 
    df = pd.read_csv(file , skiprows = 1)
    rluc = df.iloc[1:7,0::2]
    del rluc["Unnamed: 0"]
    eyfp = df.iloc[10:16,0::2]
    del eyfp["Unnamed: 0"]
    
    Rluc_row_holder = {}
    Rluc_rows = 0
    for c in char_range('a', 'h'):
        for i in range(6):
            Rluc_row_holder[f'Rluc_row_{c}_time_{(i+1)*5}'] = rluc.iloc[i,Rluc_rows::8]
        Rluc_rows = Rluc_rows + 1

    locals().update(Rluc_row_holder)
    
    yfp_row_holder = {}
    yfp_rows = 0
    for c in char_range('a', 'h'):
        for i in range(6):
            yfp_row_holder[f'yfp_row_{c}_time_{(i+1)*5}'] = eyfp.iloc[i,yfp_rows::8]
        yfp_rows = yfp_rows + 1

    locals().update(yfp_row_holder)
    
    row_holder = {}
    rows = 0
    for c in char_range('a', 'h'):
        for i in range(6):
            rluc_loc = eval('Rluc_row_'+str(c)+'_time_'+str((i+1)*5))
            yfp_loc = eval('yfp_row_'+str(c)+'_time_'+str((i+1)*5))
            row_holder[f'row_{c}_time_{(i+1)*5}'] = col_div(yfp_loc,rluc_loc)
        rows = rows + 1

    locals().update(row_holder)
    
    col_holder = {}
    cols = 0
    for i in range(12):
        for j in range(6):
            mylist = []
            for c in char_range('a','h'):
                mylist.append(eval('row_'+str(c)+'_time_'+str((j+1)*5)+'['+ str(i) +']'))
            mylist2 = np.array(mylist, dtype=np.float64)
            np.set_printoptions(formatter={'float':"{0:0.6f}".format})
            col_holder[f'col_{i+1}_time_{(j+1)*5}'] = mylist2
        cols = cols + 1

    locals().update(col_holder)
    #print(col_12_time_15)
    print('<?xml version="1.0" encoding="UTF-8"?>')
    print('<GraphPadPrismFile xmlns="http://graphpad.com/prism/Prism.htm" PrismXMLVersion="5.00">')
    print('<Created>')
    print('<OriginalVersion CreatedByProgram="GraphPad Prism" CreatedByVersion="5.0.1.334" RegisteredTo="McCorvy Lab" Login="njm3" DateTime="'+ date1 +'T'+now1 +'-06:00"/>')
    print('</Created>')
    print('<InfoSequence>')
    print('<Ref ID="Info0" Selected="1"/>')
    print('</InfoSequence>')
    print('<Info ID="Info0">')
    print('<Title>Project info 1</Title>')
    print('<Notes>')
    print('</Notes>')
    print('<Constant><Name>Experiment Date</Name><Value>2015-12-17</Value></Constant>')
    print('<Constant><Name>Experiment ID</Name><Value/></Constant>')
    print('<Constant><Name>Notebook ID</Name><Value/></Constant>')
    print('<Constant><Name>Project</Name><Value/></Constant>')
    print('<Constant><Name>Experimenter</Name><Value/></Constant>')
    print('<Constant><Name>Protocol</Name><Value/></Constant>')
    print('</Info>')
    print('')
    print('<TableSequence>')
    print('<Ref ID="Table0"/>')
    print('<Ref ID="Table17"/>')
    print('<Ref ID="Table25"/>')
    print('<Ref ID="Table33"/>')
    print('<Ref ID="Table41"/>')
    print('<Ref ID="Table63" Selected="1"/>')
    print('</TableSequence>')
    for t in [5,10,15,20,25,30]:
        if t == 5:
            print('<Table ID="Table0" XFormat="numbers" YFormat="replicates" Replicates="2" TableType="XY">')
        elif t == 10:
            print('<Table ID="Table17" XFormat="numbers" YFormat="replicates" Replicates="2" TableType="XY">')
        elif t == 15:
            print('<Table ID="Table25" XFormat="numbers" YFormat="replicates" Replicates="2" TableType="XY">')
        elif t == 20:
            print('<Table ID="Table33" XFormat="numbers" YFormat="replicates" Replicates="2" TableType="XY">')
        elif t == 25:
            print('<Table ID="Table41" XFormat="numbers" YFormat="replicates" Replicates="2" TableType="XY">')
        elif t == 30:
            print('<Table ID="Table63" XFormat="numbers" YFormat="replicates" Replicates="2" TableType="XY">')
        print('<Title>'+str(t-5)+'-'+str(t)+'min</Title>')
        print('<XColumn Width="81" Decimals="1" Subcolumns="1">')
        print('<Title>log [drug] M</Title>')
        print('<Subcolumn>')
        print('<d>-12</d>')
        print('<d>-11</d>')
        print('<d>-10</d>')
        print('<d>-9</d>')
        print('<d>-8</d>')
        print('<d>-7</d>')
        print('<d>-6</d>')
        print('<d>-5</d>')
        print('<d>-4</d>')
        print('</Subcolumn>')
        print('</XColumn>')
        for j in [1,3,5,7,9,11]:
            print('<YColumn Width="118" Decimals="3" Subcolumns="2">')
            if j == 1:
                print('<Title>drug_1</Title>')
            elif j == 3:
                print('<Title>drug_2</Title>')
            elif j == 5:
                print('<Title>drug_3</Title>')
            elif j == 7:
                print('<Title>drug_4</Title>')
            elif j == 9:
                print('<Title>drug_5</Title>')
            elif j == 11:
                print('<Title>drug_6</Title>')
            lst1 = eval('col_'+str(j)+'_time_'+str(t))    
            print('<Subcolumn>')
            print('<d/>')
            #or i in range(len(lst1)):
            #    print('<d>'+str(lst1[i])+'<d>')
            arrconv(lst1)
            print('</Subcolumn>')
            lst2 = eval('col_'+str(j+1)+'_time_'+str(t))    
            print('<Subcolumn>')
            print('<d/>')
            #for i in range(len(lst2)):
            #    print('<d>'+str(lst2[i])+'<d>')
            arrconv(lst2)
            print('</Subcolumn>')
            print('</YColumn>')
        print('</Table>')
    print('')
    print('<!--Analyses, graphs and layouts as compressed binary. Don\'t edit this part of the file.-->')
    print('')
    print('<Template xmlns:dt="urn:schemas-microsoft-com:datatypes" dt:dt="bin.base64">'+analysis+'</Template></GraphPadPrismFile>')
#pzfx_maker(file_test)

# %%
import tkinter as tk
from tkinter import Tk
from tkinter.filedialog import askdirectory
#path = askdirectory(title='Select Folder') # shows dialog box and return the path
#print(path)
from tkinter import filedialog

root = tk.Tk()
root.withdraw()

path = filedialog.askdirectory(title='Select Folder')

#mymy = input(print('Press Enter When Ready'))

# %%
import re
count = 0
ccount = 0
filedict = {}
filepats = {}
for filename in os.listdir(path):
    if filename.endswith(".csv"):
        #print(os.path.join(path, filename))
        filpat = os.path.join(path, filename)
        filetrim = str(os.path.splitext(filename)[0]+'.pzfx')
        newfp = os.path.join(path, filetrim)
        filedict[f'file_{ccount}'] = newfp
        filepats[f'filep_{ccount}'] = filpat
        ccount = ccount + 1
        count = count + 1
    elif count <= 20:
        count = count + 1
        continue
    elif count == 20:
        break
locals().update(filedict)
locals().update(filepats)
#filepats

# %%
for i in range(len(filedict)):
    newfile = eval('file_'+str(i))
    newpat = eval('filep_'+str(i))
    stdout_obj = sys.stdout 
    sys.stdout = open(newfile,'w')
    pzfx_maker(newpat)
    sys.stdout.close()
    sys.stdout = stdout_obj
